# %% [markdown]
# # 1. Importation des Librairies

# %%
# importer les Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Charger les donnees

# %%
# # Charger les donnees
data = pd.read_csv('Data/DDoS_dataset.csv')
data.head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0     3917        0      0.0       0.0      0
# 1     3520        0      0.0       0.0      0
# 2     1242        0      0.0       0.0      0
# 3     1492        0      0.0       0.0      0
# 4     3665        0      0.0       0.0      0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Étape 3 : Analyse de données

# %%
# Étape 3 : Analyse de données
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dt           104345 non-null  int64
#  1   switch       104345 non-null  int64
#  2   src          104345 non-null  object
#  3   dst          104345 non-null  object
#  4   pktcount     104345 non-null  int64
#  5   bytecount    104345 non-null  int64
#  6   dur          104345 non-null  int64
#  7   dur_nsec     104345 non-null  int64
#  8   tot_dur      104345 non-null  float64
#  9   flows        104345 non-null  int64
#  10  packetins    104345 non-null  int64
#  11  pktperflow   104345 non-null  int64
#  12  byteperflow  104345 non-null  int64
#  13  pktrate      104345 non-null  int64
#  14  Pairflow     104345 non-null  int64
#  15  Protocol     104345 non-null  object
#  16  port_no      104345 non-null  int64
#  17  tx_bytes     104345 non-null  int64
#  18  rx_bytes     104345 non-null  int64
#  19  tx_kbps      104345 non-null  int64
#  20  rx_kbps      103839 non-null  float64
#  21  tot_kbps     103839 non-null  float64
#  22  label        104345 non-null  int64
# dtypes: float64(3), int64(17), object(3)
# memory usage: 18.3+ MB

# %%
data['src'].unique()
# Out:
# array(['10.0.0.1', '10.0.0.2', '10.0.0.4', '10.0.0.10', '10.0.0.3',
#        '10.0.0.5', '10.0.0.13', '10.0.0.6', '10.0.0.20', '10.0.0.11',
#        '10.0.0.12', '10.0.0.18', '10.0.0.8', '10.0.0.7', '10.0.0.9',
#        '10.0.0.14', '10.0.0.15', '10.0.0.16', '10.0.0.17'], dtype=object)

# %%
data['dst'].unique()
# Out:
# array(['10.0.0.8', '10.0.0.7', '10.0.0.3', '10.0.0.5', '10.0.0.10',
#        '10.0.0.13', '10.0.0.1', '10.0.0.11', '10.0.0.2', '10.0.0.4',
#        '10.0.0.9', '10.0.0.6', '10.0.0.14', '10.0.0.15', '10.0.0.12',
#        '10.0.0.16', '10.0.0.17', '10.0.0.18'], dtype=object)

# %%
data['Protocol'].unique()
# Out:
# array(['UDP', 'TCP', 'ICMP'], dtype=object)

# %%
data.drop(columns='src', inplace=True, axis=1)
data.drop(columns='dst', inplace=True, axis=1)
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol port_no   tx_bytes  \
# 0       1943       13535  ...      451         0       UDP       3  143928631
# 1       1943       13531  ...      451         0       UDP       4       3842
# 2       1943       13534  ...      451         0       UDP       1       3795
# 3       1943       13534  ...      451         0       UDP       2       3688
# 4       1943       13534  ...      451         0       UDP       3       3413
#
#    rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0      3917        0      0.0       0.0      0
# 1      3520        0      0.0       0.0      0
# 2      1242        0      0.0       0.0      0
# 3      1492        0      0.0       0.0      0
# 4      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Étape 4 : Prétraitement des données

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
data['Protocol'] = encoder.fit_transform(data['Protocol'])
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol  port_no  \
# 0       1943       13535  ...      451         0         2        3
# 1       1943       13531  ...      451         0         2        4
# 2       1943       13534  ...      451         0         2        1
# 3       1943       13534  ...      451         0         2        2
# 4       1943       13534  ...      451         0         2        3
#
#     tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0  143928631      3917        0      0.0       0.0      0
# 1       3842      3520        0      0.0       0.0      0
# 2       3795      1242        0      0.0       0.0      0
# 3       3688      1492        0      0.0       0.0      0
# 4       3413      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %%
data['Protocol'].unique()
# Out:
# array([2, 1, 0])

# %%
data.isnull().sum()
# Out:
# dt               0
# switch           0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Gestion des valeurs manquantes
data['rx_kbps'].fillna(data['rx_kbps'].mean(), inplace=True)
data['tot_kbps'].fillna(data['tot_kbps'].mean(), inplace=True)
data.isnull().sum()
# Out:
# dt             0
# switch         0
# pktcount       0
# bytecount      0
# dur            0
# dur_nsec       0
# tot_dur        0
# flows          0
# packetins      0
# pktperflow     0
# byteperflow    0
# pktrate        0
# Pairflow       0
# Protocol       0
# port_no        0
# tx_bytes       0
# rx_bytes       0
# tx_kbps        0
# rx_kbps        0
# tot_kbps       0
# label          0
# dtype: int64

# %%
data
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  ...  pktrate  Pairflow  Protocol  \
# 0           3       1943       13535  ...      451         0         2
# 1           2       1943       13531  ...      451         0         2
# 2           3       1943       13534  ...      451         0         2
# 3           3       1943       13534  ...      451         0         2
# 4           3       1943       13534  ...      451         0         2
# ...       ...        ...         ...  ...      ...       ...       ...
# 104340      5         10          29  ...        0         0         0
# 104341      5         10          29  ...        0         0         0
# 104342      5         10          30  ...        1         0         0
# 104343      5         10          30  ...        1         0         0
# 104344      5         10          30  ...        1         0         0
#
#         port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0             3  143928631      3917        0      0.0       0.0      0
# 1             4       3842      3520        0      0.0       0.0      0
# 2             1       3795      1242        0      0.0       0.0      0
# 3             2       3688      1492        0      0.0       0.0      0
# 4             3       3413      3665        0      0.0       0.0      0
# ...         ...        ...       ...      ...      ...       ...    ...
# 104340        1      15209     12720        1      1.0       2.0      0
# 104341        3      15099     14693        1      1.0       2.0      0
# 104342        2       3409      3731        0      0.0       0.0      0
# 104343        1      15209     12720        1      1.0       2.0      0
# 104344        3      15099     14693        1      1.0       2.0      0
#
# [104345 rows x 21 columns]

# %% [markdown]
# # Étape 5 : Diviser les données : Train et Test (Normaliser les données)

# %%
data.columns
# Out:
# Index(['dt', 'switch', 'pktcount', 'bytecount', 'dur', 'dur_nsec', 'tot_dur',
#        'flows', 'packetins', 'pktperflow', 'byteperflow', 'pktrate',
#        'Pairflow', 'Protocol', 'port_no', 'tx_bytes', 'rx_bytes', 'tx_kbps',
#        'rx_kbps', 'tot_kbps', 'label'],
#       dtype='object')

# %%
#Étape 5 : Diviser les données : Train et Test (Normaliser les données)
#X = data.drop(columns='label', inplace=True, axis=1)
#y = data['label']
X = data.iloc[ : , :-1]
y = data.iloc[ : , -1]

# %%
X
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 0           3       1943       13535     14428310      451         0
# 1           2       1943       13531     14424046      451         0
# 2           3       1943       13534     14427244      451         0
# 3           3       1943       13534     14427244      451         0
# 4           3       1943       13534     14427244      451         0
# ...       ...        ...         ...          ...      ...       ...
# 104340      5         10          29         2842        0         0
# 104341      5         10          29         2842        0         0
# 104342      5         10          30         2940        1         0
# 104343      5         10          30         2940        1         0
# 104344      5         10          30         2940        1         0
#
#         Protocol  port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps
# 0              2        3  143928631      3917        0      0.0       0.0
# 1              2        4       3842      3520        0      0.0       0.0
# 2              2        1       3795      1242        0      0.0       0.0
# 3              2        2       3688      1492        0      0.0       0.0
# 4              2        3       3413      3665        0      0.0       0.0
# ...          ...      ...        ...       ...      ...      ...       ...
# 104340         0        1      15209     12720        1      1.0       2.0
# 104341         0        3      15099     14693        1      1.0       2.0
# 104342         0        2       3409      3731        0      0.0       0.0
# 104343         0        1      15209     12720        1      1.0       2.0
# 104344         0        3      15099     14693        1      1.0       2.0
#
# [104345 rows x 20 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
# Splitting 
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=40)

# %%
print("X-train:", X_train.shape)
print("X-test:", X_test.shape)
print("y-train:", y_train.shape)
print("y-train:", y_test.shape)
# Out:
# X-train: (80345, 20)
# X-test: (24000, 20)
# y-train: (80345,)
# y-train: (24000,)

# %% [markdown]
# # Étape 6 : Construire le Shallow Neural Network

# %%
# Étape 6 : Construire le Shallow Neural Network
# Pour installer Tensorflow : pip install tensorflow  / conda install tensorflow
# Pour installer keras : pip install keras / conda install keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
# Creation du model
model = Sequential()

# %%
# Ajout de la couche d'entree == couche cachee
model.add(Dense(10, input_shape=(20,), activation='relu'))
#model.add(Dense(16, input_shape=(9,), activation='relu'))
#model.add(Dense(32, activation='relu'))

# Ajout de la couche de sortie
model.add(Dense(1, activation='sigmoid'))

# Compiler le modele
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Affichage de l'architecture ou la structure du model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221 (884.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Entrainement du modele
history = model.fit(X_train, y_train, epochs=75, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.5271 - loss: 4075212288.0000 - val_accuracy: 0.3912 - val_loss: 72991152.0000
# Epoch 2/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.5553 - loss: 40481156.0000 - val_accuracy: 0.6406 - val_loss: 13371430.0000
# Epoch 3/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5671 - loss: 40021824.0000 - val_accuracy: 0.6369 - val_loss: 32951640.0000
# Epoch 4/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5774 - loss: 42204388.0000 - val_accuracy: 0.6119 - val_loss: 91258128.0000
# Epoch 5/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5853 - loss: 33731428.0000 - val_accuracy: 0.4067 - val_loss: 46827612.0000
# Epoch 6/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.5750 - loss: 37765644.0000 - val_accuracy: 0.6635 - val_loss: 12707948.0000
# Epoch 7/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.5949 - loss: 32280550.0000 - val_accuracy: 0.6177 - val_loss: 23382526.0000
# Epoch 8/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.5981 - loss: 31423704.0000 - val_accuracy: 0.6201 - val_loss: 18481790.0000
# Epoch 9/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5846 - loss: 38507836.0000 - val_accuracy: 0.4070 - val_loss: 102871872.0000
# Epoch 10/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5989 - loss: 33786076.0000 - val_accuracy: 0.6756 - val_loss: 11457256.0000
# Epoch 11/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.5955 - loss: 36593848.0000 - val_accuracy: 0.4776 - val_loss: 16368357.0000
# Epoch 12/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6023 - loss: 32467500.0000 - val_accuracy: 0.6969 - val_loss: 10057548.0000
# Epoch 13/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.5949 - loss: 39512368.0000 - val_accuracy: 0.4101 - val_loss: 118017360.0000
# Epoch 14/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6024 - loss: 33150372.0000 - val_accuracy: 0.6332 - val_loss: 21138868.0000
# Epoch 15/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6020 - loss: 37063020.0000 - val_accuracy: 0.4200 - val_loss: 21672118.0000
# Epoch 16/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6028 - loss: 31078052.0000 - val_accuracy: 0.6761 - val_loss: 13903532.0000
# Epoch 17/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6048 - loss: 30466454.0000 - val_accuracy: 0.6884 - val_loss: 10868126.0000
# Epoch 18/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6033 - loss: 32148392.0000 - val_accuracy: 0.6552 - val_loss: 18367042.0000
# Epoch 19/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.6057 - loss: 35978768.0000 - val_accuracy: 0.6700 - val_loss: 16054585.0000
# Epoch 20/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6136 - loss: 32047916.0000 - val_accuracy: 0.6521 - val_loss: 19343126.0000
# Epoch 21/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6090 - loss: 32462752.0000 - val_accuracy: 0.6309 - val_loss: 61189468.0000
# Epoch 22/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6178 - loss: 28624372.0000 - val_accuracy: 0.6379 - val_loss: 50459488.0000
# Epoch 23/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6084 - loss: 33810640.0000 - val_accuracy: 0.4224 - val_loss: 39642876.0000
# Epoch 24/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6054 - loss: 31454750.0000 - val_accuracy: 0.4215 - val_loss: 38286812.0000
# Epoch 25/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6120 - loss: 31919714.0000 - val_accuracy: 0.6815 - val_loss: 12518797.0000
# Epoch 26/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.6049 - loss: 33737984.0000 - val_accuracy: 0.6438 - val_loss: 38749920.0000
# Epoch 27/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.6053 - loss: 35109676.0000 - val_accuracy: 0.6851 - val_loss: 12066968.0000
# Epoch 28/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.6201 - loss: 29037856.0000 - val_accuracy: 0.6906 - val_loss: 11979013.0000
# Epoch 29/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6211 - loss: 27134300.0000 - val_accuracy: 0.6440 - val_loss: 34586852.0000
# Epoch 30/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6078 - loss: 32356488.0000 - val_accuracy: 0.4278 - val_loss: 17506516.0000
# Epoch 31/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6083 - loss: 31244452.0000 - val_accuracy: 0.6877 - val_loss: 11548751.0000
# Epoch 32/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6117 - loss: 30078840.0000 - val_accuracy: 0.6407 - val_loss: 49244128.0000
# Epoch 33/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6142 - loss: 30540686.0000 - val_accuracy: 0.6723 - val_loss: 15720627.0000
# Epoch 34/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6150 - loss: 29261636.0000 - val_accuracy: 0.4209 - val_loss: 28418906.0000
# Epoch 35/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6168 - loss: 27674292.0000 - val_accuracy: 0.6466 - val_loss: 33587296.0000
# Epoch 36/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6088 - loss: 31734610.0000 - val_accuracy: 0.6824 - val_loss: 11467653.0000
# Epoch 37/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6264 - loss: 25184854.0000 - val_accuracy: 0.4224 - val_loss: 39116868.0000
# Epoch 38/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6125 - loss: 33444800.0000 - val_accuracy: 0.4173 - val_loss: 73032200.0000
# Epoch 39/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6121 - loss: 31470142.0000 - val_accuracy: 0.6447 - val_loss: 37868456.0000
# Epoch 40/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6119 - loss: 30861084.0000 - val_accuracy: 0.6212 - val_loss: 90154232.0000
# Epoch 41/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6177 - loss: 31879506.0000 - val_accuracy: 0.6464 - val_loss: 20953244.0000
# Epoch 42/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6126 - loss: 26357248.0000 - val_accuracy: 0.6825 - val_loss: 12462690.0000
# Epoch 43/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.6105 - loss: 30260240.0000 - val_accuracy: 0.6808 - val_loss: 13584663.0000
# Epoch 44/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6089 - loss: 29968862.0000 - val_accuracy: 0.6560 - val_loss: 18678166.0000
# Epoch 45/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6133 - loss: 28340952.0000 - val_accuracy: 0.6414 - val_loss: 27001608.0000
# Epoch 46/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.6211 - loss: 26844688.0000 - val_accuracy: 0.6801 - val_loss: 13198980.0000
# Epoch 47/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 28s 11ms/step - accuracy: 0.6103 - loss: 29780244.0000 - val_accuracy: 0.6352 - val_loss: 24551874.0000
# Epoch 48/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.6092 - loss: 30168384.0000 - val_accuracy: 0.6895 - val_loss: 10455624.0000
# Epoch 49/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.6218 - loss: 26724632.0000 - val_accuracy: 0.6650 - val_loss: 16135109.0000
# Epoch 50/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6137 - loss: 31680572.0000 - val_accuracy: 0.6103 - val_loss: 178679616.0000
# Epoch 51/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6149 - loss: 32714628.0000 - val_accuracy: 0.6453 - val_loss: 20000062.0000
# Epoch 52/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6175 - loss: 29058004.0000 - val_accuracy: 0.4235 - val_loss: 30528858.0000
# Epoch 53/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - accuracy: 0.6245 - loss: 24864994.0000 - val_accuracy: 0.6898 - val_loss: 9850001.0000
# Epoch 54/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.6171 - loss: 25129914.0000 - val_accuracy: 0.6456 - val_loss: 33555972.0000
# Epoch 55/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.6134 - loss: 29102370.0000 - val_accuracy: 0.6684 - val_loss: 15677953.0000
# Epoch 56/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.6214 - loss: 26326810.0000 - val_accuracy: 0.6381 - val_loss: 28607620.0000
# Epoch 57/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - accuracy: 0.6042 - loss: 30197594.0000 - val_accuracy: 0.4231 - val_loss: 44285304.0000
# Epoch 58/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - accuracy: 0.6075 - loss: 27639240.0000 - val_accuracy: 0.6698 - val_loss: 14903850.0000
# Epoch 59/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.6112 - loss: 29184920.0000 - val_accuracy: 0.7053 - val_loss: 8949130.0000
# Epoch 60/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.6156 - loss: 30797636.0000 - val_accuracy: 0.4226 - val_loss: 35886788.0000
# Epoch 61/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - accuracy: 0.6160 - loss: 26555558.0000 - val_accuracy: 0.4195 - val_loss: 57396812.0000
# Epoch 62/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.6165 - loss: 26955944.0000 - val_accuracy: 0.6907 - val_loss: 9833479.0000
# Epoch 63/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.6148 - loss: 26315944.0000 - val_accuracy: 0.6945 - val_loss: 9506326.0000
# Epoch 64/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - accuracy: 0.6195 - loss: 24475344.0000 - val_accuracy: 0.6805 - val_loss: 12090317.0000
# Epoch 65/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.6198 - loss: 24257882.0000 - val_accuracy: 0.7080 - val_loss: 7898465.5000
# Epoch 66/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.6159 - loss: 24425076.0000 - val_accuracy: 0.4261 - val_loss: 17833858.0000
# Epoch 67/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.6249 - loss: 19835042.0000 - val_accuracy: 0.6660 - val_loss: 14229365.0000
# Epoch 68/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - accuracy: 0.6120 - loss: 25431840.0000 - val_accuracy: 0.6936 - val_loss: 8387269.5000
# Epoch 69/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.6133 - loss: 23944564.0000 - val_accuracy: 0.6892 - val_loss: 9334488.0000
# Epoch 70/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.6167 - loss: 22768114.0000 - val_accuracy: 0.6157 - val_loss: 94450672.0000
# Epoch 71/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.6184 - loss: 22489230.0000 - val_accuracy: 0.6801 - val_loss: 11318442.0000
# Epoch 72/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6139 - loss: 23999286.0000 - val_accuracy: 0.6898 - val_loss: 8075543.0000
# Epoch 73/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.6205 - loss: 21768344.0000 - val_accuracy: 0.6453 - val_loss: 32767670.0000
# Epoch 74/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6175 - loss: 23894816.0000 - val_accuracy: 0.6450 - val_loss: 33450612.0000
# Epoch 75/75
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6148 - loss: 24298896.0000 - val_accuracy: 0.4235 - val_loss: 24031334.0000

# %% [markdown]
# # Étape 7 : Visualiser l’évolution de l’entrainement du réseau de neurone

# %%
history

# %%
# Étape 7 : Visualiser l’évolution de l’entrainement du réseau de neurone
import matplotlib.pyplot as plt

# %%
epoch_accuracy = history.history['accuracy']
epoch_loss = history.history['loss']

epoch_val_accuracy = history.history['val_accuracy']
epoch_val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='red', label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Valeur')
plt.title('Accuracy Vs Loss')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_val_accuracy)), epoch_val_accuracy, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Vs Test Accuracy')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='blue', label='Training Loss')
plt.plot(range(0, len(epoch_val_loss)), epoch_val_loss, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Vs Test Loss')
plt.legend()
plt.plot()
plt.show()

# %% [markdown]
# # Étape 8 : Evaluer le modèle

# %%
# Étape 8 : Evaluer le modèle
model.evaluate(X_test, y_test)
# Out:
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4227 - loss: 24231340.0000
# [24031334.0, 0.4234583377838135]
